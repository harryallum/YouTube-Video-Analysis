# %% [markdown]
# # Set Up Environment

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import os
from googleapiclient.discovery import build
import isodate
from sqlalchemy import create_engine,text
import plotly.express as px

# %%
db_string = 'sqlite:///../db/youtube.db'

# Create a engine
engine = create_engine(db_string)
# Create connection
conn = engine.connect()

# %% [markdown]
# ## Define Functions

# %%
import pandas as pd

def filter_videos_by_duration(df, min_duration=60, max_duration=1800):
    """
    Filter videos DataFrame by duration within a specified range.
    
    Parameters:
        df (DataFrame): The DataFrame containing video data.
        min_duration (int): Minimum duration in seconds. Default is 60.
        max_duration (int): Maximum duration in seconds. Default is 1800.
        
    Returns:
        DataFrame: Filtered DataFrame containing videos with duration within the specified range.
    """
    return df[(df['duration'] >= min_duration) & (df['duration'] <= max_duration)]

# %% [markdown]
# # Import Data

# %%
# Import channels data
query = text('SELECT * FROM channel')
channels_df = pd.read_sql_query(query, conn)
channels_df.head()
# Out:
#                  channel_id      channel_name  \
# 0  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1  UCEBpSZhI1X8WaP-kY_2LLcg  365 Data Science
# 2  UCHXa4OpASJEwrHrLeIzw7Yg  Nicholas Renotte
# 3  UCDybamfye5An6p-j1t2YMsg           Mo Chen
# 4  UCkRFwipiIqBTakN-mkZ-GcQ       Ayush Singh
#
#                                          description  subscriber_count  \
# 0                            Learn to code for free.           9040000
# 1  At 365 Data Science we make #DataScience acces...            307000
# 2  Sup!\n\nWelcome to the channel. So, if you're ...            235000
# 3  👋 Hey there, my name is Mo Chen and I work as ...             82100
# 4                                                                70200
#
#    view_count  video_count               playlist_id  start_date country
# 0   661570512         1585  UU8butISFwT-Wl7EV0hUK0BQ  2014-12-16      US
# 1    13782817          224  UUEBpSZhI1X8WaP-kY_2LLcg  2017-08-07      BG
# 2    15263747          304  UUHXa4OpASJEwrHrLeIzw7Yg  2019-01-26      AU
# 3     2658864           88  UUDybamfye5An6p-j1t2YMsg  2022-12-25      GB
# 4     2075280           24  UUkRFwipiIqBTakN-mkZ-GcQ  2022-06-25      IN

# %%
# Import videos data
query = text('SELECT * FROM video')
videos_df = pd.read_sql_query(query, conn)
videos_df.head()
# Out:
#                  channel_id     video_id  \
# 0  UC8butISFwT-Wl7EV0hUK0BQ  YdWkUdMxMvM
# 1  UC8butISFwT-Wl7EV0hUK0BQ  5rNk7m_zlAg
# 2  UC8butISFwT-Wl7EV0hUK0BQ  5ZdHfJVAY-s
# 3  UC8butISFwT-Wl7EV0hUK0BQ  OwjKN9_NqPI
# 4  UC8butISFwT-Wl7EV0hUK0BQ  e2nkq3h1P68
#
#                                          video_title  \
# 0         Career Change to Code - The Complete Guide
# 1    Spring Boot & Spring Data JPA – Complete Course
# 2                 Build 25 React Projects – Tutorial
# 3  Oh My Zsh Creator Robby Russell – freeCodeCamp...
# 4           Learn Accessibility - Full a11y Tutorial
#
#                                          description tags  \
# 0  This course is for those considering transitio...
# 1  Learn how to use Spring Boot and Spring Data J...
# 2  Master React by building 25 different projects...
# 3  In this week's episode of the podcast, freeCod...
# 4  Learn how to write accessible HTML by solving ...
#
#                     published  view_count  like_count  favourite_count  \
# 0  2024-02-07 15:49:07.000000      3252.0       374.0                0
# 1  2024-02-06 15:25:40.000000     24118.0      1434.0                0
# 2  2024-02-05 15:30:28.000000     50388.0      2988.0                0
# 3  2024-02-02 15:26:29.000000     14435.0       284.0                0
# 4  2024-02-01 15:38:37.000000     23669.0       968.0                0
#
#    comment_count  duration definition caption  category_id
# 0           27.0     12191         hd   false           27
# 1          223.0     45737         hd   false           27
# 2          103.0     34614         hd   false           27
# 3           22.0      7673         hd   false           27
# 4           17.0      5586         hd   false           27

# %% [markdown]
# # Data Pre-Processing
# ## Remove shorts and longs

# %%
filtered_videos_df = filter_videos_by_duration(videos_df)

# %% [markdown]
# # Inspect Data

# %%
filtered_videos_df.head()
# Out:
#                    channel_id     video_id  \
# 57   UC8butISFwT-Wl7EV0hUK0BQ  9He4UBLyk8Y
# 134  UC8butISFwT-Wl7EV0hUK0BQ  ypNKKYUJE5o
# 158  UC8butISFwT-Wl7EV0hUK0BQ  D6Xj_W4leu8
# 489  UC8butISFwT-Wl7EV0hUK0BQ  xZbU6bCZFYo
# 496  UC8butISFwT-Wl7EV0hUK0BQ  flpmSXVTqBI
#
#                                            video_title  \
# 57                    Front End Developer Roadmap 2024
# 134  JavaScript Security Vulnerabilities Tutorial  ...
# 158  Use ChatGPT to Build a RegEx Generator – OpenA...
# 489  freeCodeCamp.org Curriculum Expansion: Math + ...
# 496                Java Testing - JUnit 5 Crash Course
#
#                                            description tags  \
# 57   Learn what technologies you should learn first...
# 134  Learn about 10 security vulnerabilities every ...
# 158  Learn how to build a dashboard that generates ...
# 489  Support our campaign here: https://www.freecod...
# 496  JUnit 5 is one of the most popular frameworks ...
#
#                       published  view_count  like_count  favourite_count  \
# 57   2023-10-19 14:18:42.000000    507722.0     17091.0                0
# 134  2023-05-16 14:37:07.000000     62016.0      2625.0                0
# 158  2023-03-30 13:32:31.000000    102762.0      2133.0                0
# 489  2021-02-02 19:00:57.000000     87027.0      3478.0                0
# 496  2021-01-12 15:59:45.000000    309188.0      5393.0                0
#
#      comment_count  duration definition caption  category_id
# 57           493.0       729         hd   false           27
# 134           71.0      1505         hd    true           27
# 158           82.0      1792         hd    true           27
# 489          197.0      1677         hd    true           27
# 496           97.0      1565         hd   false           27

# %%
filtered_videos_df['category_id'].value_counts()
# Out:
# category_id
# 27    19873
# 28     6952
# 26     1758
# 22     1637
# 24      497
# 1       185
# 17       74
# 20       48
# 19       18
# 23       12
# 25       11
# 2         8
# 15        3
# 10        2
# Name: count, dtype: int64

# %% [markdown]
# # Labelling dataset

# %%
prompt_str = """You are a classifier, and I want you to classify each of the following data science youtube video titles based on the type of video. The options for video type are: Tutorial
Project
Interview
Review
News
Tips
Career
Challenge

The output should be in a table format with the columns being the index, the prompt and the classification for that prompt.

The video titles are as below:

"""

# %%
videos_for_labelling_df = filtered_videos_df.copy().reset_index()
videos_for_labelling_df.to_csv("videos_for_labelling_df.csv")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

#print(videos_for_labelling_df['video_title'].head(300).to_string(index=False, header=False))
print((prompt_str + videos_for_labelling_df['video_title'].iloc[2900:3000].to_string(header=False)).replace('|', ''))
# Out:
# You are a classifier, and I want you to classify each of the following data science youtube video titles based on the type of video. The options for video type are: Tutorial
# Project
# Interview
# Review
# News
# Tips
# Career
# Challenge
#
# The output should be in a table format with the columns being the index, the prompt and the classification for that prompt.
#
# The video titles are as below:
#
# 2900                                                     Riddhi Jain Pitliya on virtual agents and memes #ai
# 2901                             Mahault Albarracin on intelligence #artificialintelligence #activeinference
# 2902                                                            Prof. KARL FRISTON on upcoming WOLFRAM show!
# 2903                                                      Prof. Karl Friston on Prof. Andy Clark's new book!
# 2904                         Professor Noam Chomsky on Wittgenstein's private language argument #linguistics
# 2905           Luciano Floridi on the ramifications of working in AI #machineleaning #artificialintelligence
# 2906                                                  David Chalmers on AI alignment #artificialintelligence
# 2907                                                     Yannic Kilcher on superintelligence #machineleaning
# 2908                      Prof. Richard Swinburne from Oxford University - is AGI a God? #machineleaning #ai
# 2909                                                Jessica O. Matthews on AI X-Risk #artificialintelligence
# 2910                                                   AI Meets: The Theatre [Dr. PIOTR MIROWSKI - DeepMind]
# 2911                                                  ChatGPT Simulators: Alignment in Large Language Models
# 2912                                                              Can ChatGPT Handle Infinite Possibilities?
# 2913                                                            Uncovering the Mysteries of Category Theory!
# 2914                                       Unveiling AI's Illusions: with Gary Marcus and Michael Wooldridge
# 2915                                          Can AI Ever Be Truly Conscious? Prof. Chris Eliasmith Explains
# 2916                                                                            IMPACT OF CHATGPT ON SOCIETY
# 2917                                                       Prof. Sepp Hochreiter: A Pioneer in Deep Learning
# 2918                                                                           AGI: WE ARE ALL GOING TO DIE!
# 2919                                                                        RLHF+CHATGPT: What you must know
# 2920                                      Gary Marcus on Steven Piantadosi paper on Chomsky #machinelearning
# 2921            Prof. Noam Chomsky, the father of modern linguistics, talking about ChatGPT #machinelearning
# 2922                         Prof. Chris Summerfield on creativity in large language models #machinelearning
# 2923                                                     Leetcode Challenge with DeepMind & Mila Scientists!
# 2924                              Prof. Karl Friston on multiple scales of emergence #artificialintelligence
# 2925                                                 #100 Dr. PATRICK LEWIS - Retrieval Augmented Generation
# 2926                                    #97 SREEJAN KUMAR - Human Inductive Biases in Machines from Language
# 2927                                                  #94 - ALAN CHAN - AI Alignment and Governance #NEURIPS
# 2928                     #91 - HATTIE ZHOU - Teaching Algorithmic Reasoning via In-context Learning #NeurIPS
# 2929                                       #89 Dr. ALFREDO CANZIANI - Accessibility, Visual Teaching Methods
# 2930    #87 - ADELE MYERS - Regression-Based Elastic Metric Learning on Shape Spaces of Cell Curves #NEURIPS
# 2931              #84 LAURA RUIS - Large language models are not zero-shot communicators [NEURIPS UNPLUGGED]
# 2932    #83 Dr. ANDREW LAMPINEN (Deepmind) - Natural Language, Symbols and Grounding [NEURIPS2022 UNPLUGGED]
# 2933           What Is Team Charter?  Team Charter In Project Management  Project Management  Simplilearn
# 2934            Excel Dashboard For Beginners  Excel Dashboard Tutorial  Excel Tutoring 2024  Simplilearn
# 2935          Machine Learning Kya Hai?  What Is Machine Learning In HINDI  #MachineLearning  Simplilearn
# 2936    ReactJS Components Explained  ReactJS Component Lifecycle  React JS Tutorial Simplilearn #ReactJS
# 2937          How To Build BACKLINKS For Website?  Link Building Strategies 2024  #Backlinks  Simplilearn
# 2938                                                 Lesson 1 - Digital Marketing Introduction  Simplilearn
# 2939           Simplilearn Reviews  How I Became A Full-Time Software Developer?  Aswin’s Upskilling Story
# 2940      Simplilearn's Executive Certificate Program In General Management In Collaboration With IIM Indore
# 2941                  Demilitarised Zone Explained  What Is DMZ  Cybersecurity For Beginners  Simplilearn
# 2942                                                  Lesson - 01  An Introduction to ASP.NET  Simplilearn
# 2943       How ChatGPT Works In HINDI?  ChatGPT कैसे काम करता है?  ChatGPT Explained In Hindi Simplilearn
# 2944      Tableau Dashboard Tutorial 2024  Tableau Tutorial for Beginners  #TableauDashboard  Simplilearn
# 2945    What Is Subnet Mask?  Subnet Mask Explained In 11 Minutes  Computer Networks Tutorial  Simplilearn
# 2946    Best Email Marketing Strategies For 2024  How To Do Email Marketing Case Study INCLUDEDSimplilearn
# 2947     Executive Certificate Program In General Management By Simplilearn In Collaboration With IIM Indore
# 2948    10 EFFECTIVE Marketing Strategies In 2024  Best Marketing Strategies To GROW A Business Simplilearn
# 2949     DATA VISUALIZATION In EXCEL  How To Build Interactive CHARTS In EXCEL  Simplilearn #excel #charts
# 2950                          Executive Certificate Program In General Management  IIM Indore  Simplilearn
# 2951    Data Science Kya Hai?  What Is Data Science In HINDI  Data Science For Beginners HINDISimplilearn
# 2952          12 Agile Principles Explained In 18 Minutes  Agile Principles And Methodologies  Simplilearn
# 2953        Top 20 BUSINESS ANALYST INTERVIEW QUESTIONS And ANSWERS 2024  Simplilearn #businessAnalyst #QnA
# 2954                    🔥 Fastest Way To Become A Cybersecurity Engineer And Get A Job In 2024  Simplilearn
# 2955                ChatGPT For Data Analytics  How To Use ChatGPT For Data Analysis  Simplilearn #ChatGPT
# 2956     Top 5 Certifications For Web Development 2024  5 Best Web Development Certifications  Simplilearn
# 2957                  Top 10 No CODING Jobs And 10 Best Programming Languages To Learn In 2024  Simplilearn
# 2958      Roadmap To Data Analytics In 2024  Data Analytics Career Path 2024  #DataAnalytics  Simplilearn
# 2959    Cybersecurity क्या है?  What Is Cybersecurity [Hindi] Cyber Security Explained HINDI  Simplilearn
# 2960         Social Media Marketing Roadmap 2024  How To Start Social Media Marketing In 2024  Simplilearn
# 2961     Difference Between Project Manager and Scrum Master  Project Manager Vs Scrum Master  Simplilearn
# 2962    AI Vs ML Vs DL In 2024  AI Vs Machine Learning Vs Deep Learning Differences Explained  Simplilearn
# 2963            DevOps क्या है?  What Is DevOps In HINDI?  DevOps Explained In Hindi #DevOps  Simplilearn
# 2964        What Is Default Gateway?  Default Gateway Explained In 9 Minutes  #Cybersecurity  Simplilearn
# 2965       Top 10 SEO TOOLS To Rank #1 on GOOGLE In 2024  SEO TOOLS For Beginners  Simplilearn #SEO #TOOLS
# 2966             Simplilearn Reviews: Data Analyst to Data Scientist Journey  Wendy's Story #SuccessStories
# 2967           What Is Project Q*?  All You Need To Know About Project Q-Star  OpenAI Q Star  Simplilearn
# 2968     Top 5 SKILLS To Become A DATA ENGINEER In 2024  MUST Know SKILLS For A DATA ENGINEER  Simplilearn
# 2969      What Is Artificial General Intelligence?  Artificial General Intelligence Explained  Simplilearn
# 2970                                 Top 10 Certifications And 10 Highest Paying Jobs For 2024  Simplilearn
# 2971    Top 10 Technologies To Learn And Make More Money In 2024 🤑🤑  Trending Technologies 2024 Simplilearn
# 2972    10 Effective Business Marketing Strategies For 2024  Business Marketing Tips and Tricks Simplilearn
# 2973    Difference Between AGILE And SPIRAL MODEL Explained In 15 Minutes AGILE Vs SPIRAL MODEL Simplilearn
# 2974                     What Is Cloud Computing In Hindi  Cloud Computing Explained In Hindi  Simplilearn
# 2975     Proxy vs Reverse Proxy Explained In 15 Minutes  Cybersecurity Tutorial For Beginners  Simplilearn
# 2976               Artificial Intelligence Kya Hai?  What Is Artificial Intelligence In Hindi  Simplilearn
# 2977    Top 9 Cybersecurity Trends For 2024  Top Trends In Cybersecurity You Must Know In 2024 Simplilearn
# 2978       What Is SWOT ANALYSIS?  How To Perform A SWOT ANALYSIS For Your Business  Simplilearn #Business
# 2979              Simplilearn Reviews  Saying No To Retirement With Data Science Bootcamp  Cindy’s Journey
# 2980    Top 10 Skills To Learn In 2024 10 High Income Skills  Top 10 Skills For Jobs In 2024  Simplilearn
# 2981    R vs PYTHON For DATA SCIENCE  Which Should YOU LEARN In 2024?  Simplilearn #DataScience #Python #R
# 2982     Top 10 Digital Marketing Tools To GROW Your Business In 2024  Digital Marketing 2024  Simplilearn
# 2983      50 Amazing DATA ANALYTICS Concepts Explained In 10 Minutes  DATA ANALYTICS Tutorial  Simplilearn
# 2984    Top 10 HACKING TOOLS For 2024  HACKING TOOLS You Need To LEARN In 2024  Simplilearn #hacking #Tool
# 2985               How To Set Up A Digital Marketing Agency With $0 In 2024?  Simplilearn #DigitalMarketing
# 2986     Top 10 Non Coding IT Jobs And 10 Highest Paying Jobs In 2024  No Coding IT Jobs 2024  Simplilearn
# 2987    ChatGPT Vs Gemini  Will Google's Gemini Take Over ChatGPT  ChatGPT 4 Vs Google Gemini Simplilearn
# 2988      10 FREE AI TOOLS You Won't Believe EXIST  These AI TOOLS Will Make YOU RICH  Simplilearn #AI #ML
# 2989       All About Machine Learning And Deep Learning In 2024  Simplilearn #MachineLearning #DeepLearning
# 2990      Top 5 HIGHEST PAYING Tech Skills 2024  5 Most IN DEMAND Programming Skills For 2024  Simplilearn
# 2991    How To Use DALL E Image Generator?  Dall E AI Image Generator Tutorial  OpenAI Dall-E Simplilearn
# 2992                                   Top 10 Technologies And 10 Best Certifications For 2024  Simplilearn
# 2993    How To SELL DIGITAL PRODUCTS ONLINE Step By Step GUIDE For Beginners  Simplilearn #DigitalMarketing
# 2994       WEB SCRAPPING Using CHATGPT  How To Use GPT 4 Vision API To Automate Web Scrapping  Simplilearn
# 2995               Simplilearn Reviews  Career Restart After Eight-Year-Long Career Gap  Gayatri’s Journey
# 2996     Top 10 Programming Languages And 10 Highest Paying Jobs For 2024  Trending JOBS 2024  Simplilearn
# 2997      Top 10 Technologies And 10 Highest Paying Jobs For 2024  Trending Technologies 2024  Simplilearn
# 2998           Learn Data Classes In Python In 10 Minutes  How To Use Data Classes In Python?  Simplilearn
# 2999                Top 20 Linux Distros Explained In 13 Minutes  Linux Distros for Beginners  Simplilearn

# %%
# Load the classified_titles.csv into a DataFrame
classified_df = pd.read_csv('classified_titles.csv')

# Assuming videos_for_labelling_df is already defined as a DataFrame

# Left join the two DataFrames on the index
videos_with_labelling_df = videos_for_labelling_df.merge(classified_df, how='left', left_index=True, right_index=True)

# %%
videos_with_labelling_df.head()
# Out:
#    index                channel_id     video_id  \
# 0     57  UC8butISFwT-Wl7EV0hUK0BQ  9He4UBLyk8Y
# 1    134  UC8butISFwT-Wl7EV0hUK0BQ  ypNKKYUJE5o
# 2    158  UC8butISFwT-Wl7EV0hUK0BQ  D6Xj_W4leu8
# 3    489  UC8butISFwT-Wl7EV0hUK0BQ  xZbU6bCZFYo
# 4    496  UC8butISFwT-Wl7EV0hUK0BQ  flpmSXVTqBI
#
#                                                                      video_title  \
# 0                                               Front End Developer Roadmap 2024
# 1             JavaScript Security Vulnerabilities Tutorial  – With Code Examples
# 2            Use ChatGPT to Build a RegEx Generator – OpenAI API Low Code Course
# 3  freeCodeCamp.org Curriculum Expansion: Math + Machine Learning + Data Science
# 4                                            Java Testing - JUnit 5 Crash Course
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Learn what technologies you should learn first to become a front end web developer.\nWatch the full learning front end learning path: https://www.youtube.com/playlist?list=PLWKjhJtqVAbmMuZ3saqRIBimAKIMYkt0E\n\n✏️ This video was developed by @beau \n\n🎉 Thanks to our Champion and Sponsor supporters:\n👾 davthecoder\n👾 jedi-or-sith\n👾 南宮千影\n👾 Agustín Kussrow\n👾 Nattira Maneerat\n👾 Heather Wcislo\n👾 Serhiy Kalinets\n👾 Justin Hual\n👾 Otis Morgan \n👾 Oscar Rahnama\n\n--\n\nLearn to code for free and get a developer job: https://www.freecodecamp.org\n\nRead hundreds of articles on programming: https://freecodecamp.org/news
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Learn about 10 security vulnerabilities every JavaScript developer should know. First try to find the vulnerabilities in the different code examples. Then learn how to fix the issues.\n\n✏️ Brandon from Semgrep developed this course.\n\n🔗 Learn more about Semgrep: https://go.semgrep.dev/scan-in-1-minute-for-free\n🏗 Semgrep provided a grant to make this course possible.\n\n\n\n🎉 Thanks to our Champion and Sponsor supporters:\n👾 davthecoder\n👾 jedi-or-sith\n👾 南宮千影\n👾 Agustín Kussrow\n👾 Nattira Maneerat\n👾 Heather Wcislo\n👾 Serhiy Kalinets\n👾 Justin Hual\n👾 Otis Morgan\n\n--\n\nLearn to code for free and get a developer job: https://www.freecodecamp.org\n\nRead hundreds of articles on programming: https://freecodecamp.org/news
# 2                                          Learn how to build a dashboard that generates RegEx using the OpenAI API and a low code tool called Retool. The dashboard allows users to input a string, write a description of the desired RegEx, and generate the code to transform the string accordingly. \n\n💻 You can find the iframe code here: https://github.com/kubowania/regex-openai\n\n✏️ This course was created by @AniaKubow .\n\n🏗 Retool provided a grant to make this course possible. Learn more about Retool: https://retool.com\n\n⭐️ Contents ⭐️\n(0:00) Introduction\n(2:36) Writing our own regex code\n(5:06) Creating the header element\n(8:11) Creating the text area\n(11:35) How to create a custom code editor\n(16:32) Creating the new button\n(19:08) Setting up the sidebar\n(20:58) Configuring the open api api\n(22:51) The body of the example example\n(24:58) Setting up the code\n\n🎉 Thanks to our Champion and Sponsor supporters:\n👾 Nattira Maneerat\n👾 Heather Wcislo\n👾 Serhiy Kalinets\n👾 Erdeniz Unvan\n👾 Justin Hual\n👾 Agustín Kussrow\n👾 Otis Morgan\n\n--\n\nLearn to code for free and get a developer job: https://www.freecodecamp.org\n\nRead hundreds of articles on programming: https://freecodecamp.org/news
# 3                                                                                                                                                                                                                                                                                                                                                                                                   Support our campaign here: https://www.freecodecamp.org/news/p/4476d664-eb83-47c9-8328-903a78865c8f#the-2021-data-science-curriculum-pledge-drive\n\nView the Curriculum Design Sheets (these are very much a work in progress): https://docs.google.com/spreadsheets/d/1KXEJvgnAziiePMp2Ovf_ssDqCFFWYuycXWBNp91k3qM/edit?usp=sharing\n\nIf you're a math / CS professor or Data Science practitioner, we'd appreciate your feedback / ideas for this curriculum: https://docs.google.com/forms/d/e/1FAIpQLScLiGgmYh2DxdTmPxS141J5knuOtcYN9ulOtBwsRbkuVwXRRQ/viewform?usp=sf_link\n\nFollow Quincy on Twitter: https://twitter.com/ossia\n\nFollow Eric on Twitter: https://twitter.com/erictleung\n\nFollow Tom on Twitter: https://twitter.com/moTness\n\nFollow Darrell Silver (who's 100%-matching all donations) on Twitter: https://twitter.com/darrellsilver
# 4  JUnit 5 is one of the most popular frameworks for testing Java applications. In this crash course, you will learn about Junit 5 and how to use it to write unit tests for your Java programs.\n\n✏️ Course created by Programming Techie. Check out their channel: https://www.youtube.com/channel/UCD20RZV_WHQImisCW2QZwDw\n\n💻 Source Code for Starter Project: https://github.com/SaiUpadhyayula/contact-manager-starter\n💻 Source Code for Completed Project: https://github.com/SaiUpadhyayula/contact-manager\n\n🔗 Written Tutorial: https://programmingtechie.com/2020/12/26/junit-5-complete-tutorial/\n🔗 Maven Tutorial: https://www.youtube.com/watch?v=JhSBS2OpGdU\n\n⭐️ Course Contents ⭐️\n⌨️ (00:00) Introduction\n⌨️ (00:28) What is JUnit?\n⌨️ (01:09) JUnit Architecture\n⌨️ (02:19) First JUnit Test\n⌨️ (08:26) Testing Exceptions using assertThrows()\n⌨️ (10:10) Understanding JUnit Test Lifecycle\n⌨️ (13:42) Conditional Executions\n⌨️ (15:11) Assumptions\n⌨️ (16:58) Repeated Tests\n⌨️ (18:48) Parameterized Tests\n⌨️ (23:47) Nested Tests\n⌨️ (25:22) Disabled Tests\n\n--\n\nLearn to code for free and get a developer job: https://www.freecodecamp.org\n\nRead hundreds of articles on programming: https://freecodecamp.org/news
#
#   tags                   published  view_count  like_count  favourite_count  \
# 0       2023-10-19 14:18:42.000000    507722.0     17091.0                0
# 1       2023-05-16 14:37:07.000000     62016.0      2625.0                0
# 2       2023-03-30 13:32:31.000000    102762.0      2133.0                0
# 3       2021-02-02 19:00:57.000000     87027.0      3478.0                0
# 4       2021-01-12 15:59:45.000000    309188.0      5393.0                0
#
#    comment_count  duration definition caption  category_id  Index  \
# 0          493.0       729         hd   false           27    0.0
# 1           71.0      1505         hd    true           27    1.0
# 2           82.0      1792         hd    true           27    2.0
# 3          197.0      1677         hd    true           27    3.0
# 4           97.0      1565         hd   false           27    4.0
#
#                                                                           Prompt  \
# 0                                               Front End Developer Roadmap 2024
# 1              JavaScript Security Vulnerabilities Tutorial – With Code Examples
# 2            Use ChatGPT to Build a RegEx Generator – OpenAI API Low Code Course
# 3  freeCodeCamp.org Curriculum Expansion: Math + Machine Learning + Data Science
# 4                                            Java Testing - JUnit 5 Crash Course
#
#   Classification
# 0         Career
# 1       Tutorial
# 2       Tutorial
# 3           News
# 4       Tutorial

# %%
db_string = 'sqlite:///../db/youtube.db'

# Create a engine
engine = create_engine(db_string)

videos_with_labelling_df.to_sql(name='videos_with_labelling', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# OperationalError: duplicate column name: Index
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[86], line 6
#       3 # Create a engine
#       4 engine = create_engine(db_string)
# ----> 6 videos_with_labelling_df.to_sql(name='videos_with_labelling', con=engine, if_exists='replace', index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/sql.py:1910, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1860 """
#    1861 Write records stored in a DataFrame to a SQL database.
#    1862
#    (...)
#    1906     Any additional kwargs are passed to the engine.
#    1907 """
#    1908 sql_engine = get_engine(engine)
# -> 1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    1913     if_exists=if_exists,
#    1914     index=index,
#    1915     index_label=index_label,
#    1916     schema=schema,
#    1917     dtype=dtype,
#    1918 )
#    1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    (...)
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/sql.py:1814, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1802             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1804 table = SQLTable(
#    1805     name,
#    1806     self,
#    (...)
#    1812     dtype=dtype,
#    1813 )
# -> 1814 table.create()
#    1815 return table
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/sql.py:914, in SQLTable.create(self)
#     912         raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     913 else:
# --> 914     self._execute_create()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/sql.py:900, in SQLTable._execute_create(self)
#     898 self.table = self.table.to_metadata(self.pd_sql.meta)
#     899 with self.pd_sql.run_transaction():
# --> 900     self.table.create(bind=self.pd_sql.con)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/sql/schema.py:1293, in Table.create(self, bind, checkfirst)
#    1281 def create(self, bind: _CreateDropBind, checkfirst: bool = False) -> None:
#    1282     """Issue a ``CREATE`` statement for this
#    1283     :class:`_schema.Table`, using the given
#    1284     :class:`.Connection` or :class:`.Engine`
#    (...)
#    1290
#    1291     """
# -> 1293     bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2448, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2436 def _run_ddl_visitor(
#    2437     self,
#    2438     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    2439     element: SchemaItem,
#    2440     **kwargs: Any,
#    2441 ) -> None:
#    2442     """run a DDL visitor.
#    2443
#    2444     This method is only here so that the MockConnection can change the
#    2445     options given to the visitor so that "checkfirst" is skipped.
#    2446
#    2447     """
# -> 2448     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/sql/visitors.py:671, in ExternalTraversal.traverse_single(self, obj, **kw)
#     669 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     670 if meth:
# --> 671     return meth(obj, **kw)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:957, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     948 if not self.dialect.supports_alter:
#     949     # e.g., don't omit any foreign key constraints
#     950     include_foreign_key_constraints = None
#     952 CreateTable(
#     953     table,
#     954     include_foreign_key_constraints=(
#     955         include_foreign_key_constraints
#     956     ),
# --> 957 )._invoke_with(self.connection)
#     959 if hasattr(table, "indexes"):
#     960     for index in table.indexes:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:315, in ExecutableDDLElement._invoke_with(self, bind)
#     313 def _invoke_with(self, bind):
#     314     if self._should_execute(self.target, bind):
# --> 315         return bind.execute(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:181, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     178 def _execute_on_connection(
#     179     self, connection, distilled_params, execution_options
#     180 ):
# --> 181     return connection._execute_ddl(
#     182         self, distilled_params, execution_options
#     183     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1528, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1523 dialect = self.dialect
#    1525 compiled = ddl.compile(
#    1526     dialect=dialect, schema_translate_map=schema_translate_map
#    1527 )
# -> 1528 ret = self._execute_context(
#    1529     dialect,
#    1530     dialect.execution_ctx_cls._init_ddl,
#    1531     compiled,
#    1532     None,
#    1533     execution_options,
#    1534     compiled,
#    1535 )
#    1536 if self._has_events or self.engine._has_events:
#    1537     self.dispatch.after_execute(
#    1538         self,
#    1539         ddl,
#    (...)
#    1543         ret,
#    1544     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) duplicate column name: Index
# [SQL:
# CREATE TABLE videos_with_labelling (
# 	"index" BIGINT,
# 	channel_id TEXT,
# 	video_id TEXT,
# 	video_title TEXT,
# 	description TEXT,
# 	tags TEXT,
# 	published TEXT,
# 	view_count FLOAT,
# 	like_count FLOAT,
# 	favourite_count BIGINT,
# 	comment_count FLOAT,
# 	duration BIGINT,
# 	definition TEXT,
# 	caption TEXT,
# 	category_id BIGINT,
# 	"Index" FLOAT,
# 	"Prompt" TEXT,
# 	"Classification" TEXT
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
