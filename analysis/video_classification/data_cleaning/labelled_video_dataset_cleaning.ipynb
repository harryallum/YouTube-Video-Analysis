# %%
import pandas as pd
import numpy as np

# %%
labelled_video_df = pd.read_csv('../training_dataset/labelled_video_dataset.csv', index_col=False)

# %%
labelled_video_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
labelled_video_df.head()
# Out:
#                  channel_id     video_id  \
# 0  UC4xKdmAXFh4ACyhpiQ_3qBw  a3GQBdLoUOo
# 1  UCsvqVGtbbyHaMoevxPAq9Fg  C3ilG2-tIn0
# 2  UCW5YeuERMmlnqo4oq8vwUpg  UT9zKFYr18U
# 3  UCsvqVGtbbyHaMoevxPAq9Fg  eaTC5aReb3w
# 4  UCsvqVGtbbyHaMoevxPAq9Fg  UTOebGpWfno
#
#                                          video_title  \
# 0  Why Crypto isn't coming back. I'm getting out ...
# 1  HBase Tutorial For Beginners | HBase In Hadoop...
# 2  PHP Tutorial (& MySQL) #40 - File System (part 2)
# 3  🔥 Top 10 Highest Paying Cybersecurity Jobs For...
# 4           Reasons Java Is Still Great #Simplilearn
#
#                                          description  \
# 0  Ex-Google TechLead gets out of crypto. "Tech o...
# 1  🔥Post Graduate Program In Data Engineering: ht...
# 2  Extra reading - https://www.w3schools.com/php/...
# 3  🔥Post Graduate Program In Cyber Security: http...
# 4  🔥 IITM Pravartak Professional Certificate Prog...
#
#                                                 tags  \
# 0                                                NaN
# 1  hbase tutorial for beginners, hbase, hbase tut...
# 2  php, tutorial, php tutorial, php tutorial for ...
# 3  simplilearn, highest paying cybersecurity jobs...
# 4  simplilearn, java, java programming, java codi...
#
#                     published  view_count  like_count  favourite_count  \
# 0  2022-09-23 21:26:40.000000    152212.0      4411.0                0
# 1  2015-09-11 07:03:59.000000     24552.0       112.0                0
# 2  2019-03-12 09:11:51.000000     26930.0       565.0                0
# 3  2023-09-07 14:30:22.000000      2423.0        70.0                0
# 4  2023-06-08 09:30:11.000000       658.0        27.0                0
#
#    comment_count  duration definition  caption  category_id     video_type  \
# 0         1330.0       756         hd    False           27           News
# 1            8.0      1184         hd    False           27       Tutorial
# 2           17.0       504         hd    False           27       Tutorial
# 3            3.0       850         hd    False           27  Career Advice
# 4            3.0        60         hd    False           27           News
#
#             video_topic   technologies
# 0       Business Acumen            NaN
# 1              Big Data  HBase, Hadoop
# 2  Software Engineering     PHP, MySQL
# 3  Software Engineering            NaN
# 4  Software Engineering           Java

# %% [markdown]
# ### Manually reassign video type values

# %%
labelled_video_df['video_type'].unique()
# Out:
# array(['News', 'Tutorial', 'Career Advice', 'Project',
#        'Interview Techniques', 'Tips', nan, 'Challenge',
#        'Podcast/Interview', 'Unknown', 'Discussion', 'Interview',
#        'Career Development Paths', 'None', 'Resume Building', 'Review',
#        'Product Demo', 'Job Search Strategies', 'Testimonial',
#        'Comparison', 'Data Science', 'Other', 'Lecture', 'Advertisement',
#        'Question and Answer', "Beginner's Guide/101", 'Inspiration'],
#       dtype=object)

# %%
# Manually mapping dictionary
mapping_dict = {
    'News': 'News',
    'Tutorial': 'Tutorial',
    'Career Advice': 'Career Advice',
    'Project': 'Project',
    'Interview Techniques': 'Career Advice',
    'Tips': 'Tips',
    np.nan: 'Other',
    'Challenge': 'Challenge',
    'Podcast/Interview': 'Podcast/Interview',
    'Unknown': 'Other',
    'Discussion': 'Podcast/Interview',
    'Interview': 'Podcast/Interview',
    'Career Development Paths': 'Career Advice',
    'None': 'Other',
    'Resume Building': 'Career Advice',
    'Review': 'Tips',
    'Product Demo': 'Tutorial',
    'Job Search Strategies': 'Career Advice',
    'Testimonial': 'Career Advice',
    'Comparison': 'Tips',
    'Data Science': 'Career Advice',
    'Other': 'Other',
    'Lecture': 'Tutorial',
    'Advertisement': 'Tutorial',
    'Question and Answer': 'News',
    "Beginner's Guide/101": 'Tutorial',
    'Inspiration': 'Podcast/Interview'
}

# Update 'video_type' values manually with mapping
labelled_video_df['video_type'] = labelled_video_df['video_type'].map(mapping_dict)

# %%
labelled_video_df['video_type'].unique()
# Out:
# array(['News', 'Tutorial', 'Career Advice', 'Project', 'Tips', 'Other',
#        'Challenge', 'Podcast/Interview'], dtype=object)

# %%
labelled_video_df['video_topic'].unique()
# Out:
# array(['Business Acumen', 'Big Data', 'Software Engineering',
#        'Machine Learning / AI', 'Statistics and Probability',
#        'Data Structures', 'Career Development Paths', 'Data Wrangling',
#        'Ethics and Privacy', nan, 'Cloud Computing', 'Data Visualization',
#        'JavaScript', 'Data Science', 'Freelance',
#        'Data Structures & Algorithms', 'Balancing Work and Life',
#        'Mathematics', 'Resume Building', 'Marketing',
#        'Security and Privacy', 'Data Structures and Algorithms',
#        'Data Mining', 'Data Analysis', 'Job Search Strategies',
#        'Data Security', 'Interview Techniques', 'Project Management',
#        'Design', 'Data Analytics', 'Security', 'Business Intelligence',
#        'Education', 'Career Advice', 'Data Science Basics', 'Geography',
#        'Data Engineering', 'Careers', 'Data Management', 'Finance',
#        'Other', 'Computer Science', 'Computer Vision',
#        'Natural Language Processing', 'Research', 'Algorithm',
#        'Game Design', 'Algorithms', 'Robotics', 'Blockchain',
#        'Social Media', 'None', 'Data Science Practices', 'Database',
#        'Science', 'Health', 'Data Science / Machine Learning',
#        'Educational Development', 'Computer Hardware',
#        'Data Science / AI', 'Artificial Intelligence',
#        'Data Analysis and Visualization', 'Health and Fitness',
#        'Programming', 'Game Development', 'Mathematics and Statistics',
#        'Data Science and Statistics', 'Algorithms and Data Structures',
#        'Algorithms & Data Structures', 'Internet of Things', 'Hardware',
#        'Artificial Intelligence and Machine Learning',
#        'Theoretical Computer Science', 'Electronics', 'Sports Analytics',
#        'Data Science Competitions', 'Cyber Security', 'Project Finance',
#        'Physics', 'Crypto Cryptocurrency', 'Apple', 'Metaverse',
#        'Microsoft', 'ChatGPT', 'Cybersecurity', 'Gaming',
#        'Computer Science Fundamentals', 'Graphic Design', 'The Witness',
#        'Data Science Careers', 'Data Science Applications',
#        'Blockchain and Cryptocurrencies', 'Data Privacy',
#        'Hardware / Robotics', 'Security / Encryption',
#        'Security / Privacy', 'News', 'Data Science / ML', 'Web Design',
#        'Video Editing', 'Social Network Analysis', 'Calculus',
#        'Probability and Statistics', 'Leadership', 'AI', 'DevOps',
#        'Data Warehousing', 'Tips'], dtype=object)

# %% [markdown]
# ### Assign non-existent categories to 'Other'

# %%
# List of target values
target_values = [
    "Statistics and Probability",
    "Machine Learning / AI",
    "Data Wrangling",
    "Data Visualization",
    "Data Mining",
    "Software Engineering",
    "Ethics and Privacy",
    "Cloud Computing",
    "Resume Building",
    "Job Search Strategies",
    "Interview Techniques",
    "Career Development Paths",
    "Balancing Work and Life",
    "Business Acumen"
]

# Count rows where 'video_topic' is not in the target values
count_not_in_target = labelled_video_df[~labelled_video_df['video_topic'].isin(target_values)].shape[0]

print(f'Values assigned to non-existent categories: {count_not_in_target}')
# Out:
# Values assigned to non-existent categories: 2108

# %%
# Update values in video_topic column to "Other" if not in target_values list
labelled_video_df.loc[~labelled_video_df['video_topic'].isin(target_values), 'video_topic'] = "Other"

# %%
labelled_video_df['video_topic'].unique()
# Out:
# array(['Business Acumen', 'Other', 'Software Engineering',
#        'Machine Learning / AI', 'Statistics and Probability',
#        'Career Development Paths', 'Data Wrangling', 'Ethics and Privacy',
#        'Cloud Computing', 'Data Visualization', 'Balancing Work and Life',
#        'Resume Building', 'Data Mining', 'Job Search Strategies',
#        'Interview Techniques'], dtype=object)

# %%
labelled_video_df['technologies'].unique()
# Out:
# array([nan, 'HBase, Hadoop', 'PHP, MySQL', ..., 'TakeShape',
#        'Mac OS X Terminal', 'Bokeh, Python'], dtype=object)

# %%
labelled_video_df.head()
# Out:
#                  channel_id     video_id  \
# 0  UC4xKdmAXFh4ACyhpiQ_3qBw  a3GQBdLoUOo
# 1  UCsvqVGtbbyHaMoevxPAq9Fg  C3ilG2-tIn0
# 2  UCW5YeuERMmlnqo4oq8vwUpg  UT9zKFYr18U
# 3  UCsvqVGtbbyHaMoevxPAq9Fg  eaTC5aReb3w
# 4  UCsvqVGtbbyHaMoevxPAq9Fg  UTOebGpWfno
#
#                                          video_title  \
# 0  Why Crypto isn't coming back. I'm getting out ...
# 1  HBase Tutorial For Beginners | HBase In Hadoop...
# 2  PHP Tutorial (& MySQL) #40 - File System (part 2)
# 3  🔥 Top 10 Highest Paying Cybersecurity Jobs For...
# 4           Reasons Java Is Still Great #Simplilearn
#
#                                          description  \
# 0  Ex-Google TechLead gets out of crypto. "Tech o...
# 1  🔥Post Graduate Program In Data Engineering: ht...
# 2  Extra reading - https://www.w3schools.com/php/...
# 3  🔥Post Graduate Program In Cyber Security: http...
# 4  🔥 IITM Pravartak Professional Certificate Prog...
#
#                                                 tags  \
# 0                                                NaN
# 1  hbase tutorial for beginners, hbase, hbase tut...
# 2  php, tutorial, php tutorial, php tutorial for ...
# 3  simplilearn, highest paying cybersecurity jobs...
# 4  simplilearn, java, java programming, java codi...
#
#                     published  view_count  like_count  favourite_count  \
# 0  2022-09-23 21:26:40.000000    152212.0      4411.0                0
# 1  2015-09-11 07:03:59.000000     24552.0       112.0                0
# 2  2019-03-12 09:11:51.000000     26930.0       565.0                0
# 3  2023-09-07 14:30:22.000000      2423.0        70.0                0
# 4  2023-06-08 09:30:11.000000       658.0        27.0                0
#
#    comment_count  duration definition  caption  category_id     video_type  \
# 0         1330.0       756         hd    False           27           News
# 1            8.0      1184         hd    False           27       Tutorial
# 2           17.0       504         hd    False           27       Tutorial
# 3            3.0       850         hd    False           27  Career Advice
# 4            3.0        60         hd    False           27           News
#
#             video_topic   technologies
# 0       Business Acumen            NaN
# 1                 Other  HBase, Hadoop
# 2  Software Engineering     PHP, MySQL
# 3  Software Engineering            NaN
# 4  Software Engineering           Java

# %%
# Export df to csv
labelled_video_df.to_csv('../training_dataset/cleaned_labelled_video_dataset.csv', index=False)
