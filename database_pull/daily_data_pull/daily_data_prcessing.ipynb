# %%
import pandas as pd
import os
from googleapiclient.discovery import build
import isodate
from sqlalchemy import create_engine,text

# %% [markdown]
# ### YouTube API credentials

# %%
YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=YOUTUBE_API_KEY)

# %% [markdown]
# ### Import channel IDs from CSV

# %%
# File path for CSV import
csv_file_path = '../channels/channel_ids.csv'

# Read channel IDs from CSV file into a list
import_channel_df = pd.read_csv(csv_file_path, header=None, names=["channel_id"])

# %%
import_channel_df
# Out:
#                    channel_id
# 0    UCtYLUTtgS3k1Fg4y5tAhLbw
# 1    UC4JX40jDee_tINbkjycV4Sg
# 2    UC8butISFwT-Wl7EV0hUK0BQ
# 3    UCFbNIlppjAuEX4znoulh0Cw
# 4    UC6AVa0vSrCpuskzGDDKz_EQ
# ..                        ...
# 96   UCH6gDteHtH4hg3o2343iObA
# 97   UC3iyLcDyYxk2nN7M5DsYaYQ
# 98   UC4xKdmAXFh4ACyhpiQ_3qBw
# 99   UCtC_WTVuo9k3Zol0ZB6u5mQ
# 100  UCzZMKth1Sui-nYMHBHH16Xg
#
# [101 rows x 1 columns]

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []

    try:
        # Split channel_ids list into chunks of up to 50 ids each
        id_chunks = [channel_ids[i:i+50] for i in range(0, len(channel_ids), 50)]

        for id_chunk in id_chunks:
            request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(id_chunk)
            )
            response = request.execute()

            for item in response.get('items', []):
                data = {
                    'channel_name': item['snippet']['title'],
                    'channel_id': item['id'],
                    'description': item['snippet']['description'],
                    'subscriber_count': item['statistics']['subscriberCount'],
                    'view_count': item['statistics']['viewCount'],
                    'video_count': item['statistics']['videoCount'],
                    'playlist_id': item['contentDetails']['relatedPlaylists']['uploads'],
                    'start_date': item['snippet']['publishedAt'],
                    'country': item['snippet'].get('country', None),
                }
                all_data.append(data)
    except Exception as e:
        print(f"Error occurred: {e}")

    return pd.DataFrame(all_data)

# %%
channels_df = get_channel_stats(youtube, import_channel_df['channel_id'])

# %%
channels_df
# Out:
#               channel_name                channel_id  \
# 0         Learn with Lukas  UCw_LFe2pS8x3NyipGNJgeEA
# 1            Corey Schafer  UCCezIgC97PvUuR4_gbFUs5g
# 2    Thu Vu data analytics  UCJQJAI7IjbLcpsjWdSzYz0Q
# 3          Boris Meinardus  UCBGxe5vTiVWv7e2gP6QB1Mw
# 4                  Mo Chen  UCDybamfye5An6p-j1t2YMsg
# ..                     ...                       ...
# 96          Rishabh Mishra  UC3rY5HOgbBvGmq7RnDfwF7A
# 97              Clear Code  UCznj32AM2r98hZfTxrRo9bQ
# 98          Hussein Nasser  UC_ML5xP23TOWKUcc-oAE_Eg
# 99          Darshil Parmar  UCChmJrVa8kDg05JfCmxpLRw
# 100              h-squared  UCzZMKth1Sui-nYMHBHH16Xg
#
#                                            description subscriber_count  \
# 0    Hey, I’m Lukas 👋 I learn about IT & careers an...            34500
# 1    Welcome to my Channel. This channel is focused...          1280000
# 2    Hi there! Thanks for checking out my channel. ...           213000
# 3    👨🏻‍🎓 I do paper reviews and teach AI and Machi...            27300
# 4    👋 Hey there, my name is Mo Chen and I work as ...            85300
# ..                                                 ...              ...
# 96   Education, Jobs, Career + College Tips 😉\n\nHo...           205000
# 97   I am making tutorials on coding, primarily in ...           198000
# 98   Join me as we discuss various software enginee...           382000
# 99   Freelance Data Engineer and Solution Architect...           116000
# 100                                                                   0
#
#     view_count video_count               playlist_id  \
# 0      1944838          74  UUw_LFe2pS8x3NyipGNJgeEA
# 1     93126265         232  UUCezIgC97PvUuR4_gbFUs5g
# 2      7076650          82  UUJQJAI7IjbLcpsjWdSzYz0Q
# 3       966843          59  UUBGxe5vTiVWv7e2gP6QB1Mw
# 4      2852246          98  UUDybamfye5An6p-j1t2YMsg
# ..         ...         ...                       ...
# 96    12107381          85  UU3rY5HOgbBvGmq7RnDfwF7A
# 97    12096139          46  UUznj32AM2r98hZfTxrRo9bQ
# 98    21946130         891  UU_ML5xP23TOWKUcc-oAE_Eg
# 99     5136161         144  UUChmJrVa8kDg05JfCmxpLRw
# 100          0           0  UUzZMKth1Sui-nYMHBHH16Xg
#
#                       start_date country
# 0    2020-11-26T17:38:58.614177Z      US
# 1           2006-05-31T22:49:22Z      US
# 2     2021-04-30T15:22:58.33437Z      US
# 3           2013-11-02T16:07:44Z      DE
# 4    2022-12-25T20:25:38.187653Z      GB
# ..                           ...     ...
# 96   2022-02-12T14:28:29.641872Z      IN
# 97   2019-11-25T13:11:41.329218Z    None
# 98          2014-08-19T07:33:42Z      US
# 99   2021-04-13T14:01:35.850568Z      IN
# 100  2024-02-25T16:39:09.841374Z    None
#
# [101 rows x 9 columns]

# %%
from datetime import datetime
channels_df['etl_date'] = datetime.today().strftime('%Y-%m-%d')

# %%
channels_df
# Out:
#                    channel_id                channel_name  \
# 0    UC4bIrRImqGd4Ye_KqLpLPeQ  UVA School of Data Science
# 1    UCteRPiisgIoHtMgqHegpWAQ               Sundas Khalid
# 2    UC2UXDak6o7rBm23k3Vv5dww                  Tina Huang
# 3    UC9Tl0-lzeDPH4y7LcRwRSQA                 Egor Howell
# 4    UCh1zLfuN6F_X4eoNKCsyICA                        Yosh
# ..                        ...                         ...
# 96   UCdq65x-0_G8sMhwWNgtmXaQ                 Aditi Gupta
# 97   UClb90NQQcskPUGDIXsQEz5Q               developedbyed
# 98   UCQiNyL7ik4FIlV2UCvojq0g                  Rohan Adus
# 99   UCyU5wkjgQYGRB0hIHMwm2Sg                      Syntax
# 100  UCzZMKth1Sui-nYMHBHH16Xg                   h-squared
#
#                                            description  subscriber_count  \
# 0    Official YouTube channel for the UVA School of...              1690
# 1    Hey! I am Sundas and I help you succeed in the...            198000
# 2    Hi! My name is Tina and I'm a ex-Meta data sci...            616000
# 3                          Data Science Made Simple.\n              2830
# 4    Support me on Patreon: https://patreon.com/yos...            117000
# ..                                                 ...               ...
# 96   Hey there!! I am Aditi Gupta, Founder, CEO of ...             37400
# 97   Hello my gorgeous friends on the internet, wel...            910000
# 98      I help people up-skill themselves with data.\n              8160
# 99   Hosted by Wes Bos and Scott Tolinski since 201...            347000
# 100                                                                    1
#
#      view_count  video_count               playlist_id  \
# 0        118894          197  UU4bIrRImqGd4Ye_KqLpLPeQ
# 1      10619897          131  UUteRPiisgIoHtMgqHegpWAQ
# 2      28603820          197  UU2UXDak6o7rBm23k3Vv5dww
# 3         73905           41  UU9Tl0-lzeDPH4y7LcRwRSQA
# 4      23679633            9  UUh1zLfuN6F_X4eoNKCsyICA
# ..          ...          ...                       ...
# 96      3349604          203  UUdq65x-0_G8sMhwWNgtmXaQ
# 97     53054792          245  UUlb90NQQcskPUGDIXsQEz5Q
# 98       421224          215  UUQiNyL7ik4FIlV2UCvojq0g
# 99     28844028          836  UUyU5wkjgQYGRB0hIHMwm2Sg
# 100           0            0  UUzZMKth1Sui-nYMHBHH16Xg
#
#                       start_date country    etl_date
# 0           2017-10-26T13:33:02Z      US  2024-02-28
# 1           2014-04-19T02:27:06Z      US  2024-02-28
# 2           2013-08-28T18:05:17Z      US  2024-02-28
# 3    2023-08-16T18:02:06.851027Z      GB  2024-02-28
# 4           2018-12-13T01:16:04Z    None  2024-02-28
# ..                           ...     ...         ...
# 96          2017-09-24T11:05:09Z      IN  2024-02-28
# 97          2018-05-27T14:48:23Z      GB  2024-02-28
# 98   2020-03-23T18:26:32.339179Z    None  2024-02-28
# 99          2012-01-20T02:13:54Z      US  2024-02-28
# 100  2024-02-25T16:39:09.841374Z    None  2024-02-28
#
# [101 rows x 10 columns]

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
engine = create_engine('sqlite:///../../db/youtube.db', echo = True)

# %%
# Create connection
conn = engine.connect()

# %%
# Push df to database
channels_df.to_sql(name="channels_daily_v2", con=engine, if_exists='append', index=False)
# Out:
# 2024-02-29 08:54:38,387 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-29 08:54:38,390 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("channels_daily_v2")
# 2024-02-29 08:54:38,391 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-29 08:54:38,394 INFO sqlalchemy.engine.Engine INSERT INTO channels_daily_v2 (channel_id, etl_date, channel_name, subscriber_count, view_count, video_count) VALUES (?, ?, ?, ?, ?, ?)
# 2024-02-29 08:54:38,395 INFO sqlalchemy.engine.Engine [generated in 0.00122s] [('UCw_LFe2pS8x3NyipGNJgeEA', '2024-02-29', 'Learn with Lukas', 34500, 1944838, 74), ('UCCezIgC97PvUuR4_gbFUs5g', '2024-02-29', 'Corey Schafer', 1280000, 93126265, 232), ('UCJQJAI7IjbLcpsjWdSzYz0Q', '2024-02-29', 'Thu Vu data analytics', 213000, 7076650, 82), ('UCBGxe5vTiVWv7e2gP6QB1Mw', '2024-02-29', 'Boris Meinardus', 27300, 966843, 59), ('UCDybamfye5An6p-j1t2YMsg', '2024-02-29', 'Mo Chen', 85300, 2852246, 98), ('UCsvqVGtbbyHaMoevxPAq9Fg', '2024-02-29', 'Simplilearn', 3770000, 337448546, 7272), ('UCFbNIlppjAuEX4znoulh0Cw', '2024-02-29', 'Web Dev Simplified', 1510000, 134242548, 678), ('UCcJQ96WlEhJ0Ve0SLmU310Q', '2024-02-29', 'Internet Made Coder', 317000, 14805957, 140)  ... displaying 10 of 202 total bound parameter sets ...  ('UCyU5wkjgQYGRB0hIHMwm2Sg', '2024-02-28', 'Syntax', 347000, 28844028, 836), ('UCzZMKth1Sui-nYMHBHH16Xg', '2024-02-28', 'h-squared', 1, 0, 0)]
# 2024-02-29 08:54:38,396 INFO sqlalchemy.engine.Engine COMMIT
# 202

# %%
# Close the connection
conn.close()
engine.dispose()
# Out:
# 2024-02-29 08:49:50,152 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# Test database with simple query
query = text('ALTER TABLE channels_daily_v2 RENAME TO channels_daily;')
# channels_df = pd.read_sql_query(query, conn)

# Execute the query using SQLAlchemy's execution methods
result = conn.execute(query)
# Out:
# 2024-02-29 08:58:45,889 INFO sqlalchemy.engine.Engine ALTER TABLE channels_daily_v2 RENAME TO channels_daily;
# 2024-02-29 08:58:45,891 INFO sqlalchemy.engine.Engine [generated in 0.00210s] ()

# %%
channels_df
# Out:
#                    channel_id    etl_date           channel_name  \
# 0    UCw_LFe2pS8x3NyipGNJgeEA  2024-02-29       Learn with Lukas
# 1    UCCezIgC97PvUuR4_gbFUs5g  2024-02-29          Corey Schafer
# 2    UCJQJAI7IjbLcpsjWdSzYz0Q  2024-02-29  Thu Vu data analytics
# 3    UCBGxe5vTiVWv7e2gP6QB1Mw  2024-02-29        Boris Meinardus
# 4    UCDybamfye5An6p-j1t2YMsg  2024-02-29                Mo Chen
# ..                        ...         ...                    ...
# 197  UCdq65x-0_G8sMhwWNgtmXaQ  2024-02-28            Aditi Gupta
# 198  UClb90NQQcskPUGDIXsQEz5Q  2024-02-28          developedbyed
# 199  UCQiNyL7ik4FIlV2UCvojq0g  2024-02-28             Rohan Adus
# 200  UCyU5wkjgQYGRB0hIHMwm2Sg  2024-02-28                 Syntax
# 201  UCzZMKth1Sui-nYMHBHH16Xg  2024-02-28              h-squared
#
#      subscriber_count  view_count  video_count
# 0               34500     1944838           74
# 1             1280000    93126265          232
# 2              213000     7076650           82
# 3               27300      966843           59
# 4               85300     2852246           98
# ..                ...         ...          ...
# 197             37400     3349604          203
# 198            910000    53054792          245
# 199              8160      421224          215
# 200            347000    28844028          836
# 201                 1           0            0
#
# [202 rows x 6 columns]
